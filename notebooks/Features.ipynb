# %%
import pandas as pd
import numpy as np
from shapely.geometry import Polygon
import re

# %%
def area(x):
    
    return Polygon(x).area


def join_list(x):
    
    return ''.join(x)


def text_type(x):
    
    try:
        float(x)
        return 0

    except ValueError:

        return 1


def extrac_numbers(x):
    
    return re.sub('[^0-9,.]', "", x)


def number_type(x):
    
    try:
        float(x)
        return 1

    except ValueError:
        try:
            float(x.replace(',', '.'))

            return 1
    
        except ValueError:
            return 0
        
        
def number(x):
    
    try:
        return float(x)

    except ValueError:
        try:
            return float(x.replace(',', '.'))
    
        except ValueError:
            return 0

# %%
def get_features(df):
    
    # area
    columns = ['block_vert',
               'paragraph_vert',
               'word_vert',
              ]
    for col in columns:
        df[col.replace('vert', 'area')] = df[col].apply(area)
        
    # weighted area
    columns = ['block_area',
               'paragraph_area',
               'word_area',
              ]
    for col in columns:
        df[col.replace('area', 'weigh')] = df[col].divide(df[col].max())
        
    # relative area
    df.loc[:, 'rel_word_block_area'] = df['word_area'].divide(df['block_area'])
    df.loc[:, 'rel_word_parag_area'] = df['word_area'].divide(df['paragraph_area'])
    df.loc[:, 'rel_parag_block_area'] = df['paragraph_area'].divide(df['block_area'])
    
    # join text
    df.loc[:, 'text_join'] = df['text'].apply(join_list)
    
    # prev symbol
    df.loc[:, 'prev_symbol'] = np.where(df['symbol_search_pos'].shift(-1), 1, 0)
    df.loc[:, 'prev_symbol'] = df.loc[:, 'prev_symbol'].fillna(0)
    
    # next symbol
    df.loc[:, 'next_symbol'] = np.where(df['symbol_search_pos'].shift(1), 1, 0)
    df.loc[:, 'next_symbol'] = df.loc[:, 'next_symbol'].fillna(0)
    
    # text type
    df.loc[:, 'text_type'] = df['text_join'].apply(text_type)
    
    # prev text type
    df.loc[:, 'prev_text_type'] = df['text_type'].shift(1)
    df.loc[:, 'prev_text_type'] = df.loc[:, 'prev_text_type'].fillna(0)
    
    # next text tpye
    df.loc[:, 'next_text_type'] = df['text_type'].shift(-1)
    df.loc[:, 'next_text_type'] = df.loc[:, 'next_text_type'].fillna(0)
    
    # text len
    df.loc[:, 'text_len'] = df['text_join'].str.len()
    
    # is symbol
    df.loc[:, 'is_a_symbol'] = np.where(df['symbol_search_pos'], 1, 0)
    
    # extract numbers
    df.loc[:, 'text_numbers'] = df['text_join'].apply(extrac_numbers)
    
    # number type
    df.loc[:, 'number_type'] = df['text_numbers'].apply(number_type)
    
    # number
    df.loc[:, 'number'] = df['text_join'].apply(number)
    
    return df

# %%
df = pd.read_csv('../data/preprocessed/data.csv', index_col=[0,1])

# %%
df.shape
# Out:
# (432, 16)

# %%
from ast import literal_eval

# %%
columns = ['block_vert', 'paragraph_vert', 'word_vert', 'text']

# %%
for col in columns:
    
    df[col] = df[col].apply(literal_eval)

# %%
df_features = pd.DataFrame()

# %%
for i in df.index.get_level_values(0).unique():
    
    df_temp = df.loc[df.index.get_level_values(0)==i,:].copy()
    df_features = df_features.append(get_features(df_temp), ignore_index=True)

# %%
df_features.shape
# Out:
# (432, 36)

# %%
df_features.sample(3).T
# Out:
#                                                                    296  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              4
# block_vert            [(401, 271), (619, 255), (625, 330), (407, 346)]
# block_confidence                                                  0.97
# n_paragraph                                                          0
# paragraph_vert        [(401, 271), (619, 255), (625, 330), (407, 346)]
# paragraph_confidence                                              0.97
# n_word                                                               0
# word_vert             [(401, 271), (420, 270), (425, 344), (407, 346)]
# word_confidence                                                   0.99
# text                                                               [$]
# symbol_search_pos                                                 True
# n_symbol_search_find                                                 0
# y                                                                    0
# block_area                                                       16446
# paragraph_area                                                   16446
# word_area                                                       1386.5
# block_weigh                                                   0.239526
# paragraph_weigh                                               0.885813
# word_weigh                                                   0.0815924
# rel_word_block_area                                          0.0843062
# rel_word_parag_area                                          0.0843062
# rel_parag_block_area                                                 1
# text_join                                                            $
# prev_symbol                                                          0
# next_symbol                                                          0
# text_type                                                            1
# prev_text_type                                                       1
# next_text_type                                                       0
# text_len                                                             1
# is_a_symbol                                                          1
# text_numbers
# number_type                                                          0
# number                                                               0
#
#                                                                     165  \
# n_page                                                                0
# page_height                                                         960
# page_width                                                         1280
# n_block                                                               0
# block_vert            [(294, 368), (1042, 334), (1044, 376), (296, 4...
# block_confidence                                                   0.93
# n_paragraph                                                           0
# paragraph_vert        [(294, 368), (1042, 334), (1044, 376), (296, 4...
# paragraph_confidence                                               0.93
# n_word                                                                2
# word_vert              [(588, 355), (674, 351), (676, 393), (590, 397)]
# word_confidence                                                    0.96
# text                                                       [C, O, L, A]
# symbol_search_pos                                                 False
# n_symbol_search_find                                                NaN
# y                                                                     0
# block_area                                                        31484
# paragraph_area                                                    31484
# word_area                                                          3620
# block_weigh                                                           1
# paragraph_weigh                                                       1
# word_weigh                                                     0.304765
# rel_word_block_area                                            0.114979
# rel_word_parag_area                                            0.114979
# rel_parag_block_area                                                  1
# text_join                                                          COLA
# prev_symbol                                                           0
# next_symbol                                                           0
# text_type                                                             1
# prev_text_type                                                        1
# next_text_type                                                        1
# text_len                                                              4
# is_a_symbol                                                           0
# text_numbers
# number_type                                                           0
# number                                                                0
#
#                                                                    293
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              2
# block_vert            [(569, 151), (647, 155), (646, 172), (568, 168)]
# block_confidence                                                  0.95
# n_paragraph                                                          0
# paragraph_vert        [(569, 151), (647, 155), (646, 172), (568, 168)]
# paragraph_confidence                                              0.95
# n_word                                                               1
# word_vert             [(621, 154), (647, 155), (646, 172), (620, 171)]
# word_confidence                                                   0.96
# text                                                   [u, n, i, d, a]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    0
# block_area                                                        1330
# paragraph_area                                                    1330
# word_area                                                          443
# block_weigh                                                  0.0193707
# paragraph_weigh                                              0.0716363
# word_weigh                                                   0.0260696
# rel_word_block_area                                           0.333083
# rel_word_parag_area                                           0.333083
# rel_parag_block_area                                                 1
# text_join                                                        unida
# prev_symbol                                                          0
# next_symbol                                                          0
# text_type                                                            1
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             5
# is_a_symbol                                                          0
# text_numbers
# number_type                                                          0
# number                                                               0

# %%
df_features[df_features['y']==1].T
# Out:
#                                                                    22   \
# n_page                                                               0
# page_height                                                        719
# page_width                                                        1280
# n_block                                                              5
# block_vert            [(433, 437), (752, 423), (756, 526), (437, 540)]
# block_confidence                                                  0.98
# n_paragraph                                                          0
# paragraph_vert        [(433, 437), (752, 423), (756, 526), (437, 540)]
# paragraph_confidence                                              0.98
# n_word                                                               1
# word_vert             [(505, 434), (752, 424), (756, 526), (509, 537)]
# word_confidence                                                   0.98
# text                                                   [8, 7, ., 5, 0]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       32913
# paragraph_area                                                   32913
# word_area                                                      25359.5
# block_weigh                                                    0.25241
# paragraph_weigh                                                 0.9711
# word_weigh                                                           1
# rel_word_block_area                                           0.770501
# rel_word_parag_area                                           0.770501
# rel_parag_block_area                                                 1
# text_join                                                        87.50
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             5
# is_a_symbol                                                          0
# text_numbers                                                     87.50
# number_type                                                          1
# number                                                            87.5
#
#                                                                    54   \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              4
# block_vert            [(411, 286), (638, 260), (646, 338), (420, 363)]
# block_confidence                                                  0.98
# n_paragraph                                                          0
# paragraph_vert        [(411, 286), (638, 260), (646, 338), (420, 363)]
# paragraph_confidence                                              0.98
# n_word                                                               1
# word_vert             [(463, 280), (638, 260), (647, 338), (472, 357)]
# word_confidence                                                   0.98
# text                                                   [8, 7, ., 5, 0]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                     17770.5
# paragraph_area                                                 17770.5
# word_area                                                        13738
# block_weigh                                                    0.24147
# paragraph_weigh                                               0.911541
# word_weigh                                                    0.856164
# rel_word_block_area                                           0.773079
# rel_word_parag_area                                           0.773079
# rel_parag_block_area                                                 1
# text_join                                                        87.50
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             5
# is_a_symbol                                                          0
# text_numbers                                                     87.50
# number_type                                                          1
# number                                                            87.5
#
#                                                                    74   \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(259, 273), (534, 271), (535, 353), (260, 355)]
# block_confidence                                                  0.49
# n_paragraph                                                          0
# paragraph_vert        [(259, 273), (534, 271), (535, 353), (260, 355)]
# paragraph_confidence                                              0.49
# n_word                                                               2
# word_vert             [(399, 272), (510, 271), (511, 353), (400, 354)]
# word_confidence                                                    0.7
# text                                                         [1, 5, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       22552
# paragraph_area                                                   22552
# word_area                                                         9103
# block_weigh                                                    0.85736
# paragraph_weigh                                                0.85736
# word_weigh                                                           1
# rel_word_block_area                                           0.403645
# rel_word_parag_area                                           0.403645
# rel_parag_block_area                                                 1
# text_join                                                          152
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       152
# number_type                                                          1
# number                                                             152
#
#                                                                    100  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              2
# block_vert            [(449, 248), (587, 244), (589, 319), (451, 323)]
# block_confidence                                                  0.99
# n_paragraph                                                          0
# paragraph_vert        [(449, 248), (587, 244), (589, 319), (451, 323)]
# paragraph_confidence                                              0.99
# n_word                                                               0
# word_vert             [(449, 248), (587, 244), (589, 319), (451, 323)]
# word_confidence                                                   0.99
# text                                                         [1, 2, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       10358
# paragraph_area                                                   10358
# word_area                                                        10358
# block_weigh                                                   0.845137
# paragraph_weigh                                               0.845137
# word_weigh                                                           1
# rel_word_block_area                                                  1
# rel_word_parag_area                                                  1
# rel_parag_block_area                                                 1
# text_join                                                          122
# prev_symbol                                                          1
# next_symbol                                                          0
# text_type                                                            0
# prev_text_type                                                       0
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       122
# number_type                                                          1
# number                                                             122
#
#                                                                    112  \
# n_page                                                               0
# page_height                                                        719
# page_width                                                        1280
# n_block                                                              2
# block_vert            [(743, 318), (858, 296), (868, 348), (753, 370)]
# block_confidence                                                  0.79
# n_paragraph                                                          0
# paragraph_vert        [(743, 318), (858, 296), (868, 348), (753, 370)]
# paragraph_confidence                                              0.79
# n_word                                                               0
# word_vert             [(743, 318), (832, 301), (842, 353), (753, 370)]
# word_confidence                                                   0.99
# text                                                         [1, 2, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                        6200
# paragraph_area                                                    6200
# word_area                                                         4798
# block_weigh                                                          1
# paragraph_weigh                                                      1
# word_weigh                                                           1
# rel_word_block_area                                           0.773871
# rel_word_parag_area                                           0.773871
# rel_parag_block_area                                                 1
# text_join                                                          122
# prev_symbol                                                          0
# next_symbol                                                          0
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       122
# number_type                                                          1
# number                                                             122
#
#                                                                    123  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              2
# block_vert            [(479, 145), (704, 143), (705, 198), (480, 200)]
# block_confidence                                                  0.52
# n_paragraph                                                          0
# paragraph_vert        [(479, 145), (704, 143), (705, 198), (480, 200)]
# paragraph_confidence                                              0.52
# n_word                                                               0
# word_vert             [(479, 145), (548, 144), (549, 199), (480, 200)]
# word_confidence                                                   0.99
# text                                                            [8, 7]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       12377
# paragraph_area                                                   12377
# word_area                                                         3796
# block_weigh                                                          1
# paragraph_weigh                                                      1
# word_weigh                                                    0.711394
# rel_word_block_area                                           0.306698
# rel_word_parag_area                                           0.306698
# rel_parag_block_area                                                 1
# text_join                                                           87
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       0
# text_len                                                             2
# is_a_symbol                                                          0
# text_numbers                                                        87
# number_type                                                          1
# number                                                              87
#
#                                                                    146  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(423, 152), (569, 144), (573, 224), (427, 232)]
# block_confidence                                                  0.94
# n_paragraph                                                          0
# paragraph_vert        [(423, 152), (569, 144), (573, 224), (427, 232)]
# paragraph_confidence                                              0.94
# n_word                                                               1
# word_vert             [(470, 150), (569, 145), (573, 223), (474, 229)]
# word_confidence                                                   0.95
# text                                                            [8, 7]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       11712
# paragraph_area                                                   11712
# word_area                                                       7793.5
# block_weigh                                                          1
# paragraph_weigh                                                      1
# word_weigh                                                           1
# rel_word_block_area                                           0.665429
# rel_word_parag_area                                           0.665429
# rel_parag_block_area                                                 1
# text_join                                                           87
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       0
# text_len                                                             2
# is_a_symbol                                                          0
# text_numbers                                                        87
# number_type                                                          1
# number                                                              87
#
#                                                                    172  \
# n_page                                                               0
# page_height                                                        960
# page_width                                                        1280
# n_block                                                              1
# block_vert            [(509, 472), (654, 474), (653, 581), (508, 579)]
# block_confidence                                                  0.99
# n_paragraph                                                          0
# paragraph_vert        [(509, 472), (654, 474), (653, 581), (508, 579)]
# paragraph_confidence                                              0.99
# n_word                                                               1
# word_vert             [(543, 472), (654, 473), (653, 580), (542, 579)]
# word_confidence                                                   0.99
# text                                                            [8, 7]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       15517
# paragraph_area                                                   15517
# word_area                                                        11878
# block_weigh                                                   0.492854
# paragraph_weigh                                               0.492854
# word_weigh                                                           1
# rel_word_block_area                                           0.765483
# rel_word_parag_area                                           0.765483
# rel_parag_block_area                                                 1
# text_join                                                           87
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       0
# text_len                                                             2
# is_a_symbol                                                          0
# text_numbers                                                        87
# number_type                                                          1
# number                                                              87
#
#                                                                    201  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(388, 216), (535, 236), (523, 323), (376, 303)]
# block_confidence                                                  0.94
# n_paragraph                                                          0
# paragraph_vert        [(388, 216), (535, 236), (523, 323), (376, 303)]
# paragraph_confidence                                              0.94
# n_word                                                               1
# word_vert             [(424, 221), (535, 236), (523, 323), (412, 308)]
# word_confidence                                                   0.96
# text                                                         [1, 5, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       13029
# paragraph_area                                                   13029
# word_area                                                         9837
# block_weigh                                                   0.488563
# paragraph_weigh                                               0.488563
# word_weigh                                                           1
# rel_word_block_area                                           0.755008
# rel_word_parag_area                                           0.755008
# rel_parag_block_area                                                 1
# text_join                                                          152
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       0
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       152
# number_type                                                          1
# number                                                             152
#
#                                                                    230  \
# n_page                                                               0
# page_height                                                        719
# page_width                                                        1280
# n_block                                                              1
# block_vert            [(677, 332), (814, 343), (807, 419), (671, 408)]
# block_confidence                                                  0.91
# n_paragraph                                                          0
# paragraph_vert        [(677, 332), (814, 343), (807, 419), (671, 408)]
# paragraph_confidence                                              0.91
# n_word                                                               1
# word_vert             [(707, 334), (814, 343), (807, 418), (701, 410)]
# word_confidence                                                   0.98
# text                                                         [1, 5, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                     10445.5
# paragraph_area                                                 10445.5
# word_area                                                         8096
# block_weigh                                                   0.599782
# paragraph_weigh                                               0.599782
# word_weigh                                                     0.58771
# rel_word_block_area                                           0.775071
# rel_word_parag_area                                           0.775071
# rel_parag_block_area                                                 1
# text_join                                                          152
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       152
# number_type                                                          1
# number                                                             152
#
#                                                                    268  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              4
# block_vert            [(382, 274), (622, 245), (633, 330), (392, 359)]
# block_confidence                                                  0.99
# n_paragraph                                                          0
# paragraph_vert        [(382, 274), (622, 245), (633, 330), (392, 359)]
# paragraph_confidence                                              0.99
# n_word                                                               1
# word_vert             [(437, 267), (623, 244), (633, 330), (447, 352)]
# word_confidence                                                   0.99
# text                                                   [8, 7, ., 5, 0]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       20747
# paragraph_area                                                   20747
# word_area                                                        16128
# block_weigh                                                   0.244146
# paragraph_weigh                                               0.893497
# word_weigh                                                           1
# rel_word_block_area                                           0.777365
# rel_word_parag_area                                           0.777365
# rel_parag_block_area                                                 1
# text_join                                                        87.50
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             5
# is_a_symbol                                                          0
# text_numbers                                                     87.50
# number_type                                                          1
# number                                                            87.5
#
#                                                                    297  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              4
# block_vert            [(401, 271), (619, 255), (625, 330), (407, 346)]
# block_confidence                                                  0.97
# n_paragraph                                                          0
# paragraph_vert        [(401, 271), (619, 255), (625, 330), (407, 346)]
# paragraph_confidence                                              0.97
# n_word                                                               1
# word_vert             [(451, 267), (620, 255), (625, 329), (457, 342)]
# word_confidence                                                   0.97
# text                                                   [8, 7, ., 5, 0]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       16446
# paragraph_area                                                   16446
# word_area                                                        12622
# block_weigh                                                   0.239526
# paragraph_weigh                                               0.885813
# word_weigh                                                    0.742776
# rel_word_block_area                                           0.767481
# rel_word_parag_area                                           0.767481
# rel_parag_block_area                                                 1
# text_join                                                        87.50
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             5
# is_a_symbol                                                          0
# text_numbers                                                     87.50
# number_type                                                          1
# number                                                            87.5
#
#                                                                    314  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(376, 243), (759, 248), (758, 320), (375, 315)]
# block_confidence                                                  0.46
# n_paragraph                                                          0
# paragraph_vert        [(376, 243), (759, 248), (758, 320), (375, 315)]
# paragraph_confidence                                              0.46
# n_word                                                               1
# word_vert             [(403, 244), (500, 245), (499, 316), (402, 315)]
# word_confidence                                                   0.97
# text                                                         [1, 5, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       27581
# paragraph_area                                                   27581
# word_area                                                         6888
# block_weigh                                                          1
# paragraph_weigh                                                      1
# word_weigh                                                    0.976052
# rel_word_block_area                                           0.249737
# rel_word_parag_area                                           0.249737
# rel_parag_block_area                                                 1
# text_join                                                          152
# prev_symbol                                                          0
# next_symbol                                                          1
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       152
# number_type                                                          1
# number                                                             152
#
#                                                                    341  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(454, 197), (547, 198), (546, 273), (453, 272)]
# block_confidence                                                  0.99
# n_paragraph                                                          0
# paragraph_vert        [(454, 197), (547, 198), (546, 273), (453, 272)]
# paragraph_confidence                                              0.99
# n_word                                                               0
# word_vert             [(454, 197), (547, 198), (546, 273), (453, 272)]
# word_confidence                                                   0.99
# text                                                            [8, 7]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                        6976
# paragraph_area                                                    6976
# word_area                                                         6976
# block_weigh                                                    0.73914
# paragraph_weigh                                                0.73914
# word_weigh                                                           1
# rel_word_block_area                                                  1
# rel_word_parag_area                                                  1
# rel_parag_block_area                                                 1
# text_join                                                           87
# prev_symbol                                                          0
# next_symbol                                                          0
# text_type                                                            0
# prev_text_type                                                       0
# next_text_type                                                       0
# text_len                                                             2
# is_a_symbol                                                          0
# text_numbers                                                        87
# number_type                                                          1
# number                                                              87
#
#                                                                    363  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(450, 250), (635, 247), (636, 309), (451, 312)]
# block_confidence                                                  0.69
# n_paragraph                                                          0
# paragraph_vert        [(450, 250), (635, 247), (636, 309), (451, 312)]
# paragraph_confidence                                              0.69
# n_word                                                               1
# word_vert             [(489, 249), (594, 247), (595, 309), (490, 311)]
# word_confidence                                                   0.91
# text                                                         [1, 2, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       11473
# paragraph_area                                                   11473
# word_area                                                         6512
# block_weigh                                                          1
# paragraph_weigh                                                      1
# word_weigh                                                           1
# rel_word_block_area                                           0.567593
# rel_word_parag_area                                           0.567593
# rel_parag_block_area                                                 1
# text_join                                                          122
# prev_symbol                                                          0
# next_symbol                                                          0
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       122
# number_type                                                          1
# number                                                             122
#
#                                                                    377  \
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              1
# block_vert            [(272, 203), (568, 200), (569, 276), (273, 279)]
# block_confidence                                                  0.56
# n_paragraph                                                          0
# paragraph_vert        [(272, 203), (568, 200), (569, 276), (273, 279)]
# paragraph_confidence                                              0.56
# n_word                                                               1
# word_vert             [(408, 202), (526, 201), (527, 277), (409, 278)]
# word_confidence                                                   0.83
# text                                                         [1, 2, 2]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    1
# block_area                                                       22499
# paragraph_area                                                   22499
# word_area                                                         8969
# block_weigh                                                          1
# paragraph_weigh                                                      1
# word_weigh                                                           1
# rel_word_block_area                                            0.39864
# rel_word_parag_area                                            0.39864
# rel_parag_block_area                                                 1
# text_join                                                          122
# prev_symbol                                                          0
# next_symbol                                                          0
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# text_len                                                             3
# is_a_symbol                                                          0
# text_numbers                                                       122
# number_type                                                          1
# number                                                             122
#
#                                                                     397  \
# n_page                                                                0
# page_height                                                        4032
# page_width                                                         3024
# n_block                                                               3
# block_vert            [(953, 2028), (1653, 2017), (1660, 2433), (960...
# block_confidence                                                   0.99
# n_paragraph                                                           0
# paragraph_vert        [(953, 2028), (1653, 2017), (1660, 2433), (960...
# paragraph_confidence                                               0.99
# n_word                                                                0
# word_vert             [(953, 2028), (1653, 2017), (1660, 2433), (960...
# word_confidence                                                    0.99
# text                                                          [1, 4, 3]
# symbol_search_pos                                                 False
# n_symbol_search_find                                                NaN
# y                                                                     1
# block_area                                                       291277
# paragraph_area                                                   291277
# word_area                                                        291277
# block_weigh                                                           1
# paragraph_weigh                                                       1
# word_weigh                                                            1
# rel_word_block_area                                                   1
# rel_word_parag_area                                                   1
# rel_parag_block_area                                                  1
# text_join                                                           143
# prev_symbol                                                           0
# next_symbol                                                           1
# text_type                                                             0
# prev_text_type                                                        1
# next_text_type                                                        1
# text_len                                                              3
# is_a_symbol                                                           0
# text_numbers                                                        143
# number_type                                                           1
# number                                                              143
#
#                                                                     419
# n_page                                                                0
# page_height                                                        4032
# page_width                                                         3024
# n_block                                                               2
# block_vert            [(1024, 1856), (2173, 1880), (2162, 2391), (10...
# block_confidence                                                   0.99
# n_paragraph                                                           0
# paragraph_vert        [(1024, 1856), (2173, 1880), (2162, 2391), (10...
# paragraph_confidence                                               0.99
# n_word                                                                0
# word_vert             [(1024, 1856), (2173, 1880), (2162, 2391), (10...
# word_confidence                                                    0.99
# text                                                          [1, 1, 4]
# symbol_search_pos                                                 False
# n_symbol_search_find                                                NaN
# y                                                                     1
# block_area                                                       587403
# paragraph_area                                                   587403
# word_area                                                        587403
# block_weigh                                                           1
# paragraph_weigh                                                       1
# word_weigh                                                            1
# rel_word_block_area                                                   1
# rel_word_parag_area                                                   1
# rel_parag_block_area                                                  1
# text_join                                                           114
# prev_symbol                                                           0
# next_symbol                                                           0
# text_type                                                             0
# prev_text_type                                                        0
# next_text_type                                                        1
# text_len                                                              3
# is_a_symbol                                                           0
# text_numbers                                                        114
# number_type                                                           1
# number                                                              114

# %%
df_features.to_csv('../data/processed/data.csv')
