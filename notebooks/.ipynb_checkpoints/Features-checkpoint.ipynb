# %%
import pandas as pd
import numpy as np
from shapely.geometry import Polygon
import re

# %%
def area(x):
    
    return Polygon(x).area


def join_list(x):
    
    return ''.join(x)


def text_type(x):
    
    try:
        float(x)
        return 0

    except ValueError:

        return 1


def extrac_numbers(x):
    
    return re.sub('[^0-9,]', "", x)


def number_type(x):
    
    try:
        float(x)
        return 1

    except ValueError:
        try:
            float(x.replace(',', '.'))

            return 1
    
        except ValueError:
            return 0
        
        
def number(x):
    
    try:
        return float(x)

    except ValueError:
        try:
            return float(x.replace(',', '.'))
    
        except ValueError:
            return 0
        

def extrac_numbers(x):
    
    return re.sub('[^0-9,]', "", x)


def number_type(x):
    
    try:
        float(x)
        return 1

    except ValueError:
        try:
            float(x.replace(',', '.'))

            return 1
    
        except ValueError:
            return 0

        
def number(x):
    
    try:
        return float(x)

    except ValueError:
        try:
            return float(x.replace(',', '.'))
    
        except ValueError:
            return 0

# %%
def get_features(df):
    
    # area
    columns = ['block_vert',
               'paragraph_vert',
               'word_vert',
              ]
    for col in columns:
        df[col.replace('vert', 'area')] = df[col].apply(area)
    
    # join text
    df.loc[:, 'text_join'] = df['text'].apply(join_list)
    
    # prev symbol
    df.loc[:, 'prev_symbol'] = np.where(df['symbol_search_pos'].shift(1), 1, 0)
    df.loc[:, 'prev_symbol'] = df.loc[:, 'prev_symbol'].fillna(0)
    
    # text type
    df.loc[:, 'text_type'] = df['text_join'].apply(text_type)
    
    # prev text type
    df.loc[:, 'prev_text_type'] = df['text_type'].shift(1)
    df.loc[:, 'prev_text_type'] = df.loc[:, 'prev_text_type'].fillna(0)
    
    # next text tpye
    df.loc[:, 'next_text_type'] = df['text_type'].shift(-1)
    df.loc[:, 'next_text_type'] = df.loc[:, 'next_text_type'].fillna(0)
    
    # relative area
    df.loc[:, 'rel_word_block_area'] = df['word_area'].divide(df['block_area'])
    df.loc[:, 'rel_word_parag_area'] = df['word_area'].divide(df['paragraph_area'])
    df.loc[:, 'rel_parag_block_area'] = df['paragraph_area'].divide(df['block_area'])
    
    # text len
    df.loc[:, 'text_len'] = df['text_join'].str.len()
    
    # is symbol
    df.loc[:, 'is_a_symbol'] = np.where(df['symbol_search_pos'], 1, 0)
    
    # extract numbers
    df.loc[:, 'text_numbers'] = df['text_join'].apply(extrac_numbers)
    
    # number type
    df.loc[:, 'number_type'] = df['text_numbers'].apply(number_type)
    
    # number
    df.loc[:, 'number'] = df['text_numbers'].apply(number)
    
    return df

# %%
df = pd.read_csv('../data/preprocessed/data.csv', index_col=[0,1])

# %%
df.shape
# Out:
# (432, 16)

# %%
from ast import literal_eval

# %%
columns = ['block_vert', 'paragraph_vert', 'word_vert', 'text']

# %%
for col in columns:
    
    df[col] = df[col].apply(literal_eval)

# %%
df = get_features(df)

# %%
df.shape
# Out:
# (432, 32)

# %%
df.sample(3).T
# Out:
# file                                                            14.jpg  \
# index                                                               4
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              0
# block_vert            [(308, 136), (737, 140), (737, 162), (308, 158)]
# block_confidence                                                  0.85
# n_paragraph                                                          0
# paragraph_vert        [(308, 136), (737, 140), (737, 162), (308, 158)]
# paragraph_confidence                                              0.85
# n_word                                                               4
# word_vert             [(598, 139), (603, 139), (603, 160), (598, 160)]
# word_confidence                                                   0.92
# text                                                               [-]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    0
# block_area                                                        9438
# paragraph_area                                                    9438
# word_area                                                          105
# text_join                                                            -
# prev_symbol                                                          0
# text_type                                                            1
# prev_text_type                                                       0
# next_text_type                                                       1
# rel_word_block_area                                          0.0111252
# rel_word_parag_area                                          0.0111252
# rel_parag_block_area                                                 1
# text_len                                                             1
# is_a_symbol                                                          0
# text_numbers
# number_type                                                          0
# number                                                               0
#
# file                                                            13.jpg  \
# index                                                               20
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              3
# block_vert            [(309, 332), (493, 329), (494, 366), (310, 369)]
# block_confidence                                                   0.8
# n_paragraph                                                          1
# paragraph_vert        [(343, 352), (488, 350), (488, 366), (343, 368)]
# paragraph_confidence                                              0.76
# n_word                                                               0
# word_vert             [(343, 352), (395, 351), (395, 367), (343, 368)]
# word_confidence                                                   0.97
# text                                                [O, R, I, G, E, N]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    0
# block_area                                                        6811
# paragraph_area                                                    2320
# word_area                                                          832
# text_join                                                       ORIGEN
# prev_symbol                                                          0
# text_type                                                            1
# prev_text_type                                                       0
# next_text_type                                                       1
# rel_word_block_area                                           0.122155
# rel_word_parag_area                                           0.358621
# rel_parag_block_area                                          0.340625
# text_len                                                             6
# is_a_symbol                                                          0
# text_numbers
# number_type                                                          0
# number                                                               0
#
# file                                                            14.jpg
# index                                                               3
# n_page                                                               0
# page_height                                                        581
# page_width                                                        1032
# n_block                                                              0
# block_vert            [(308, 136), (737, 140), (737, 162), (308, 158)]
# block_confidence                                                  0.85
# n_paragraph                                                          0
# paragraph_vert        [(308, 136), (737, 140), (737, 162), (308, 158)]
# paragraph_confidence                                              0.85
# n_word                                                               3
# word_vert             [(553, 139), (591, 139), (591, 160), (553, 160)]
# word_confidence                                                   0.79
# text                                                      [1, ., 2, 5]
# symbol_search_pos                                                False
# n_symbol_search_find                                               NaN
# y                                                                    0
# block_area                                                        9438
# paragraph_area                                                    9438
# word_area                                                          798
# text_join                                                         1.25
# prev_symbol                                                          0
# text_type                                                            0
# prev_text_type                                                       1
# next_text_type                                                       1
# rel_word_block_area                                          0.0845518
# rel_word_parag_area                                          0.0845518
# rel_parag_block_area                                                 1
# text_len                                                             4
# is_a_symbol                                                          0
# text_numbers                                                       125
# number_type                                                          1
# number                                                             125

# %%
df.to_csv('../data/processed/data.csv')
